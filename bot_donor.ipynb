За 72 часа — лекарства с аспирином и анальгетиками
За час до процедуры — курение
*Лучшее время для донации*:\n
Утренние часы, до 12:00 (после полудня — только постоянным донорам)\n
*Не планируйте сдачу крови*:\n
После ночного дежурства или бессонной ночи
Перед экзаменами, соревнованиями, сдачей проекта
В период интенсивной работы\nБолее подробно по [ссылке](https://yadonor.ru/donorstvo/become/recommendations/)
'''
privileges='''
*В день донации*:\n
*Освобождение от работы*:\n
В день сдачи крови и ее компонентов, а также в день связанного с этим медицинского осмотра донор освобождается от работы с сохранением среднего заработка.
Если донор по соглашению с администрацией вышел на работу в день сдачи крови (за исключением работ с вредными и опасными условиями труда), ему предоставляется другой день отдыха с сохранением среднего заработка.\n
*Питание*:\n
Учреждение службы крови обеспечивает донора бесплатным питанием или денежной компенсацией на питание.\n
*Дополнительный день отдыха*:\n
При сдаче крови в период отпуска, в выходной или праздничный день предоставляется другой день отдыха.
Если кровь сдавалась в период освобождения от работы по болезни, другой день отдыха не предоставляется.
После каждого дня сдачи крови предоставляется дополнительный день отдыха, который может быть присоединен к отпуску или использован в течение года со дня сдачи крови.
Работодатель сохраняет за работником средний заработок за дни сдачи крови и предоставленные дни отдыха.\n
*Регулярным донорам*:\n
Доноры, сдавшие кровь и (или) ее компоненты в суммарном количестве, равном двум максимально допустимым дозам в течение года, имеют право на первоочередное приобретение льготных путевок для санаторно-курортного лечения по месту работы или учебы.\n
Подробную информацию о льготах для почетных доноров вы можете узнать на [сайте](https://yadonor.ru/donorstvo/become/privileges/). Размер выплат зависит от региона.
'''  
def question_next(message, number_question, question):
    markup=types.InlineKeyboardMarkup()
    yes_btn=types.InlineKeyboardButton(text='Да', callback_data=f'test_yes_{number_question}')
    no_btn=types.InlineKeyboardButton(text='Нет', callback_data=f'test_no_{number_question}')
    markup.add(yes_btn, no_btn)
    bot.send_message(message.chat.id, question, reply_markup=markup)
    
    
@bot.callback_query_handler(func=lambda call: call.data.startswith('test'))
def callback_inline(call):
    if int(call.data.split('_')[2])==1:
        if call.data.split('_')[1]=='yes':
            question_next(call.message, int(call.data.split('_')[2])+1,'Ваш вес больше 50 кг?')
        else:
            bot.send_message(call.message.chat.id, 'Сожалеем, донорами могут стать только совершеннолетние лица')
    elif int(call.data.split('_')[2])==2:
        if call.data.split('_')[1]=='yes':
            question_next(call.message, int(call.data.split('_')[2])+1, 'Были ли диагностированы у вас онкологические заболевания?')
        else:
            bot.send_message(call.message.chat.id, 'Сожалеем, донорами могут быть только лица с весом более 50 кг')
    elif int(call.data.split('_')[2])==3:
        if call.data.split('_')[1]=='no':
            question_next(call.message, int(call.data.split('_')[2])+1, 'У вас был диагностирован ВИЧ, гепатит В или С, сифилис, туберкулез?')
        else:
            bot.send_message(call.message.chat.id, 'Сожалеем, вы не можете быть донором')
    elif int(call.data.split('_')[2])==4:
        if call.data.split('_')[1]=='no':
            question_next(call.message, int(call.data.split('_')[2])+1, 'У вас были диагностированы заболевания сердечно-сосудистой системы: гипертоническая болезнь сердца II - III степени, ишемическая болезнь сердца, тромбофлебит, порок сердца ?')
        else:
            bot.send_message(call.message.chat.id, 'Сожалеем, вы не можете быть донором')
    elif int(call.data.split('_')[2])==5:
        if call.data.split('_')[1]=='no':
            question_next(call.message, int(call.data.split('_')[2])+1, 'У вас диагностирована бронхиальная астма?')
        else:
            bot.send_message(call.message.chat.id, 'Сожалеем, вы не можете быть донором')
    elif int(call.data.split('_')[2])==6:
        if call.data.split('_')[1]=='no':
            question_next(call.message, int(call.data.split('_')[2])+1, 'Делали ли вы лечебные или косметические процедуры с нарушением кожного покрова (татуировки, пирсинг, иглоукалывание) в течение последних 4-х месяцев?')
        else:
            bot.send_message(call.message.chat.id, 'Сожалеем, вы не можете быть донором')
    elif int(call.data.split('_')[2])==7:
        if call.data.split('_')[1]=='no':
            question_next(call.message, int(call.data.split('_')[2])+1, 'У вас были оперативные вмешательства, в том числе искусственное прерывание беременности в течение последних 4-х месяцев?')
        else:
            bot.send_message(call.message.chat.id, 'Сожалеем, вы временно не можете быть донором до истечения указанного срока')
    elif int(call.data.split('_')[2])==8:
        if call.data.split('_')[1]=='no':
            question_next(call.message, int(call.data.split('_')[2])+1, 'Делали вы прививку от коронавируса менее 1 месяца назад?')
        else:
            bot.send_message(call.message.chat.id, 'Сожалеем, вы временно не можете быть донором до истечения указанного срока')
    elif int(call.data.split('_')[2])==9:
        if call.data.split('_')[1]=='no':
            question_next(call.message, int(call.data.split('_')[2])+1, 'Для женщин: были ли у Вас роды менее года назад, беременны ли вы в настоящее время, кормите ли вы грудью в настоящее время?')
        else:
            bot.send_message(call.message.chat.id, 'Сожалеем, вы временно не можете быть донором до истечения указанного срока')
    elif int(call.data.split('_')[2])==10:
        if call.data.split('_')[1]=='no':
            question_next(call.message, int(call.data.split('_')[2])+1, 'Делали ли вам переливание крови или ее компонентов в течение последних 4-х месяцев?')
        else:
            bot.send_message(call.message.chat.id, 'Сожалеем, вы временно не можете быть донором до истечения указанного срока')
    elif int(call.data.split('_')[2])==11:
        if call.data.split('_')[1]=='no':
            question_next(call.message, int(call.data.split('_')[2])+1, 'Вы страдаете близорукостью (от минус шести диоптрий) или такими болезнями глаз как увеит или трахома?')
        else:
            bot.send_message(call.message.chat.id, 'Сожалеем, вы временно не можете быть донором до истечения указанного срок')
    elif int(call.data.split('_')[2])==12:
        if call.data.split('_')[1]=='no':
            question_next(call.message, int(call.data.split('_')[2])+1, 'Болели ли вы ОРВИ, ангиной или гриппом в течение последнего месяца?')
        else:
            bot.send_message(call.message.chat.id, 'Сожалеем, вы не можете быть донором')   
    elif int(call.data.split('_')[2])==13:
        if call.data.split('_')[1]=='no':
            question_next(call.message, int(call.data.split('_')[2])+1, 'Были ли диагностированы у вас болезни крови?')
        else:
            bot.send_message(call.message.chat.id, 'Сожалеем, вы временно не можете быть донором до истечения указанного срока')
    elif int(call.data.split('_')[2])==14:
        if call.data.split('_')[1]=='no':
            bot.send_message(call.message.chat.id, 'Поздравляем, вы можете быть донором крови, для записи выберите один из адресов Службы крови')
        else:
            bot.send_message(call.message.chat.id, 'Сожалеем, вы не можете быть донором')
                             
                             
                             
def send_test(message):
    markup=types.InlineKeyboardMarkup()
    yes_btn=types.InlineKeyboardButton(text='Да', callback_data='test_yes_1')
    no_btn=types.InlineKeyboardButton(text='Нет', callback_data='test_no_1')
    markup.add(yes_btn, no_btn)
    bot.send_message(message.from_user.id, 'Ваш возраст больше 18 лет?', reply_markup=markup)

@bot.message_handler(commands=['start'])
def start(message):
    markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
    btn1 = types.KeyboardButton('Привет!👋 Хочу больше узнать о донорстве')
    markup.add(btn1)
    bot.send_message(message.from_user.id, "Привет! Этот бот создан для помощи людям, которые хотят узнать больше о донорстве 👋", reply_markup=markup)

@bot.message_handler(content_types=['text'])
def get_text_messages(message):
    if message.text=='Привет!👋 Хочу больше узнать о донорстве':
        markup=types.ReplyKeyboardMarkup(resize_keyboard=True)
        btn1=types.KeyboardButton('Кто может стать донором?')
        btn2=types.KeyboardButton('Тест: могу ли я быть донором')
        btn3=types.KeyboardButton('Адреса центров приема')
        btn4=types.KeyboardButton('Виды донорства')
        btn5=types.KeyboardButton('Правила подготовки к сдаче')
        btn6=types.KeyboardButton('Льготы и преимущества для доноров')
        markup.add(btn1, btn2, btn3, btn4, btn5, btn6)
        bot.send_message(message.from_user.id, 'Выбери вопрос, на который хочешь получить ответ', reply_markup=markup)

    if message.text=='Кто может стать донором?':
        bot.send_message(message.from_user.id, instructions, parse_mode='Markdown')
        with open('donor.jpg', 'rb') as jpg:
            bot.send_document(message.chat.id, jpg)

    elif message.text=='Адреса центров приема':
        bot.send_message(message.from_user.id, limitations, parse_mode='Markdown')
    
    elif message.text=='Виды донорства':
        bot.send_message(message.from_user.id, 'В РФ возможно стать донором [крови](https://kkck.ru/donor/vidy-donacij/) (цельной или ее компонентов), [костного мозга](https://kmdonor.ru/), волос, внутренних органов и т.д. Более подробно ознакомиться со списком можно по [ссылке](https://journal.tinkoff.ru/short/what-to-donate/).', parse_mode='Markdown')
    
    elif message.text=='Правила подготовки к сдаче':
        bot.send_message(message.from_user.id, instructions, parse_mode='Markdown')
        with open('recommendations.jpg', 'rb') as jpg:
            bot.send_document(message.chat.id, jpg)
    
    elif message.text=='Льготы и преимущества для доноров':
        bot.send_message(message.from_user.id, privileges, parse_mode='Markdown')
    
    elif message.text=='Тест: могу ли я быть донором':
        send_test(message)
    else: 
        bot.send_message(message.from_user.id, 'Я не знаю такой команды, выберите из предложенных')
bot.polling(none_stop=True, interval=0)
